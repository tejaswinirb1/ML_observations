# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswinirb1/ML_observations/blob/main/PCA_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

# Load the iris dataset
iris =load_iris()

# Convert to DataFrame for easy plotting
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})  # Map labels to names

# Pair plot to visualize feature relationships
sns.pairplot(df, hue="species", diag_kind="kde", palette="husl")
plt.show()

# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
import pandas as pd
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)


# Now you can use .head()
iris_df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df['target'] = iris.target
iris_df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)  # Choose the desired number of components
X_pca = pca.fit_transform(X_scaled)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Visualization of Iris Dataset')
plt.show()
